# %% [markdown]
# <a href="https://colab.research.google.com/github/JamesCobley/PolyForm/blob/main/Example_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --no-cache-dir polyform-lattice
import polyform
print(polyform.__file__)      # .../dist-packages/polyform/__init__.py
print(polyform.__version__)   # 0.1.1
# Out:
# ...
# /usr/local/lib/python3.12/dist-packages/polyform/__init__.py
# 0.1.2

# %%
import polyform
print([f for f in dir(polyform) if f.startswith("run_")])
# -> ['run_figure2', 'run_support_mode', 'run_topology', 'run_weight_mode']
# Out:
# ['run_support_mode', 'run_topology', 'run_weight_mode']

# %%
res = polyform.run_support_mode(csv="proteoforms.csv", outdir="out_support")
res["global"]
# Out:
# Reading: proteoforms.csv
# Canonical sequences resolved for 1,995 / 1,995 proteins (source: Isoform Sequence)
#
# ...
# POLYFORM GLOBAL SUPPORT-MODE STRUCTURAL SUMMARY
# ...
# Records                                      9,706
# Proteins analysed                            1,995
# PTM-bearing records, valid binary             7,165
# Binary k=0 records                            2,541
# Total accessed binary states                  6,430
# Total observed fibres                         7,671
# log10 total possible state space sum_i 2^L    1,260.11
# log10 global accessed support                 3.81
# log10 global state-access fraction            -1,256.30
# Median accessed states per protein            1
# Max accessed states per protein               125
# Median log10 state-access fraction            -68.03
# Median occupied grades                        1
# Median grade span delta_k                     0
# Max grade span delta_k                        13
# ...
